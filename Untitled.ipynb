# %%
import pandas as pd

# %%
a = pd.read_csv('data1.csv')

# %%
a['new_t'].dtype
# Out:
# dtype('int64')

# %%
a
# Out:
#                    fbid             t             n  gender fb_birthday  \
# 0       100012998502085  8.416752e+11       Lee Mến  female         NaN
# 1       100012998505399  8.494547e+10  Hoàng Giagia     NaN         NaN
# 2       100012998505466  8.416798e+11      Thoại Mỹ     NaN         NaN
# 3       100012998506290  8.412142e+11           NaN     NaN         NaN
# 4       100012998506320  8.494286e+10           NaN     NaN         NaN
# ...                 ...           ...           ...     ...         ...
# 999993  100008735949725  8.490318e+10   Tien Trtien     NaN         NaN
# 999994  100008735950736  8.492728e+10           NaN     NaN         NaN
# 999995  100008735951932  8.418689e+11    Công Khanh    male         NaN
# 999996  100008735954541  8.416677e+11           NaN     NaN         NaN
# 999997  100008735956728  8.494806e+10           NaN     NaN         NaN
#
#        fb_email                          a      new_t  isVn_phone  \
# ...
